# %%
from aiogram import Bot, types
from aiogram.dispatcher import Dispatcher
from aiogram.utils import executor
from aiogram import types
from aiogram.types import ReplyKeyboardRemove, \
    ReplyKeyboardMarkup, KeyboardButton, \
    InlineKeyboardMarkup, InlineKeyboardButton

import nest_asyncio

TOKEN = ''
price = ''
suma = 0
star = "✨"
lover = "🥰"
bot = Bot(token=TOKEN)
dp = Dispatcher(bot)

@dp.message_handler(commands=['start'])
async def process_start_command(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = ["سبد","درباره ما","قیمت"]
    keyboard.add(*buttons)
    await message.answer("سلام✨\nما با شما هستیم که بیشترین سودها را در بازارهای مالی داشته باشید" + lover, reply_markup=keyboard)

@dp.message_handler(lambda message: message.text in ["قیمت","جستجو برای یکی دیگر"])
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = ["بمب افکن","فوم جامد","نمک دریایی","اسکراب","جعبه ها"]
    keyboard.add(*buttons)
    await message.answer("انتخاب کنید چه چیزی در سفارش شما خواهد بود:", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "بمب افکن")
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "با نمک دریایی", "بمب با مروارید", "دونات", "قلب", "بمب درخت کریسمس", "مینی کمان", "winno kotel", "عشق کاسه", "شب هالووین"
        ]
    keyboard.add(*buttons)
    await message.answer("در اینجا انواع بمب هایی هستند که می توانید سفارش دهید", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "با نمک دریایی")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/5rqh9tcrg3e0p0a/%D0%B1%D0%BE%D0%BC%D0%B1%D0%BE%D1%87%D0%BA%D0%B0%20%D0%B7%20%D0%BC%D0%BE%D1%80%D1%81%D1%8C%D0%BA%D0%BE%D1%8E%20%D1%81%D1%96%D0%BB%D0%BB%D1%8E.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "به سبد خرید (بمب با نمک دریایی)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "بمب با مروارید")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/z7209hdjrwbwo09/%D0%B1%D0%BE%D0%BC%D0%B1%D0%BE%D1%87%D0%BA%D0%B0%20%D0%B7%20%D0%BF%D0%B5%D1%80%D0%BB%D0%B0%D0%BC%D1%83%D1%82%D1%80%D0%BE%D0%BC%20.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب با مروارید)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "دونات")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/nvccg84puzfsqri/%D0%B1%D0%BE%D0%BC%D0%B1%D0%BE%D1%87%D0%BA%D0%B0%20%D0%BF%D0%BE%D0%BD%D1%87%D0%B8%D0%BA.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (دونات بمب)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "قلب")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/pkqa1gckuqc22xp/%D0%B1%D0%BE%D0%BC%D0%B1%D0%BE%D1%87%D0%BA%D0%B0%20%D1%81%D0%B5%D1%80%D1%86%D0%B5.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب قلب)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "بمب درخت کریسمس")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/bceitytlbiban9x/%D0%B1%D0%BE%D0%BC%D0%B1%D0%BE%D1%87%D0%BA%D0%B0%20%D1%8F%D0%BB%D0%B8%D0%BD%D0%BA%D0%B0.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب درخت کریسمس)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "مینی کمان")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/362gqgt65jzyj06/%D0%BC%D1%96%D0%BD%D1%96-%D0%BC%D1%96%D0%BD%D1%96%20%D1%87%D0%B0%D1%88%D0%B0.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب کوچک کاسه)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "winno kotel")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/hwc3z6g77fq939l/%D0%BC%D1%96%D0%BD%D1%96-%D1%87%D0%B0%D1%88%D0%B0.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب Wizhmin Kotel)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "عشق کاسه")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/2p0jx0i818rp69r/%D1%87%D0%B0%D1%88%D0%B0%20%D0%BA%D0%BE%D1%85%D0%B0%D0%BD%D0%BD%D1%8F.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب کاسه عشق)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "شب هالووین")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/zb5pnodm8v0zwcp/%D1%85%D0%B5%D0%BB%D0%BB%D0%BE%D0%B2%D1%96%D1%96%D0%BD%D1%81%D1%8C%D0%BA%D0%B0%20%D0%BD%D1%96%D1%87.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (بمب شب هالووین)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "فوم جامد")
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "ستاره", "درخت", "آب نبات"
        ]
    keyboard.add(*buttons)
    await message.answer("در اینجا انواع فوم جامد است که شما می توانید سفارش دهید", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "ستاره")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/x7681ark3k6pppf/%D0%B7%D1%96%D1%80%D0%BA%D0%B8.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (یک ستاره فوم سخت)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "درخت")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/x7y6szapg2l0ljt/%D1%82%D0%B2%D0%B5%D1%80%D0%B4%D0%B0%20%D0%BF%D1%96%D0%BD%D0%B0%20%D1%8F%D0%BB%D0%B8%D0%BD%D0%BA%D0%B0.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (درخت فوم محکم)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "آب نبات")
async def registration(message: types.Message):
    await bot.send_photo(message.from_user.id, "https://www.dropbox.com/s/jznze9z082cq1y0/%D1%82%D0%B2%D0%B5%D1%80%D0%B4%D0%B0%20%D0%BF%D1%96%D0%BD%D0%B0%20%D1%86%D1%83%D0%BA%D0%B5%D1%80%D0%BA%D0%B0.jpg?dl=0")
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "افزودن به سبد خرید (فوم جامد آب نبات)", "جستجو برای یکی دیگر"
        ]
    keyboard.add(*buttons)
    await message.answer("گرفتن?)", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "نمک دریایی")
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "استاندارد", "با مروارید", "با فوم"
        ]
    keyboard.add(*buttons)
    await message.answer("در اینجا انواع نمک دریایی است که می توانید سفارش دهید:", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "اسکراب")
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "رافالو","صبح"
        ]
    keyboard.add(*buttons)
    await message.answer("در اینجا انواع اسکراب است که می توانید سفارش دهید", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "جعبه ها")
async def registration(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "جعبه ها"
    ]
    keyboard.add(*buttons)
    await message.answer("در اینجا انواع جعبه هایی است که می توانید سفارش دهید", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب با نمک دریایی)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 60
    price += " (بمب با نمک دریایی) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب با مروارید)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 45
    price += " (بمب با مروارید) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (دونات بمب)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 65
    price += " (دونات بمب گذاری) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب قلب)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 40
    price += " (بمب قلب) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب درخت کریسمس)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 80
    price += " (بمب درخت کریسمس) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب کوچک کاسه)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 45
    price += " (بمب کوچک کاسه) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب Wizhmin Kotel)")
async def registration(message: types.Message):
    global price
    global suma
    suma += 45
    price += " (بمب Wizhmin Kotel) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب کاسه عشق)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 90
    price += " (بمب عشق کاسه) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (بمب شب هالووین)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 80
    price += " (بمب شب هالووین) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (یک ستاره فوم سخت)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 30
    price += " (ستاره فوم سخت) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (درخت فوم محکم)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 30
    price += " (درخت فوم محکم) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "افزودن به سبد خرید (فوم جامد آب نبات)")
async def registration(message: types.Message):
    global suma
    global price
    suma += 40
    price += " (فوم جامد آب نبات) "
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == 'درباره ما')
async def cmd_inline_url(message: types.Message):
    buttons = [
        types.InlineKeyboardButton(text="instagram - Kings_Bombs", url="https://instagram.com/kings_bombs_?utm_medium=copy_link"),
        types.InlineKeyboardButton(text="tik tok - Kings_Bombs", url="https://vm.tiktok.com/ZMLFrw4j8/")
    ]
    keyboard = types.InlineKeyboardMarkup(resize_keyboard=True)
    keyboard.add(*buttons)
    await message.answer("صفحات ما در شبکه های اجتماعی", reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "سبد")
async def registration(message: types.Message):
    global price
    global suma
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    buttons = [
        "پاک کردن","سفارش"
    ]
    keyboard.add(*buttons)
    await message.answer("شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma), reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "پاک کردن")
async def registration(message: types.Message):
    global price
    global suma
    global many
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))
    await bot.send_message(message.from_user.id, "تمیز کردن...")
    price = ""
    many = 0
    suma = 0
    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

@dp.message_handler(lambda message: message.text == "سفارش")
async def registration(message: types.Message):
    global price
    global suma
    await bot.send_message(337646093, "====================================")
    await bot.send_message(337646093, "سفارش: " + price)
    await bot.send_message(337646093, "قیمت: "+ str(suma))
    await bot.send_message(337646093, "@"+message.from_user.username)
    await bot.send_message(337646093, "====================================")

    await bot.send_message(message.from_user.id, "شما سفارش دادید: "+price+"\nبه اندازه ی: "+str(suma))

    await bot.send_message(367471403, "====================================")
    await bot.send_message(367471403, "سفارش: " + price)
    await bot.send_message(367471403, "قیمت: "+ str(suma))
    await bot.send_message(367471403, "@"+message.from_user.username)
    await bot.send_message(367471403, "====================================")

@dp.message_handler()
async def echo_message(msg: types.Message):
    await bot.send_message(msg.from_user.id, "نوشتن /start")

if __name__ == '__main__':
    nest_asyncio.apply()
   # __import__('IPython').embed()
    executor.start_polling(dp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from aiogram import Bot, types
#       2 from aiogram.dispatcher import Dispatcher
#       3 from aiogram.utils import executor
#
# ModuleNotFoundError: No module named 'aiogram'
